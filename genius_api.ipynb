# %%
import lyricsgenius as lg

# %%
api = lg.Genius('EkwclsJky_nfkcWhnpOfQu-99mxmOPMe6r_gcPxPUOxtVslEytkjhzBvTOjxzBhn')

# %%
song = api.search_song('iz')
# Out:
# Searching for "iz"...
# Done.

# %%
song.year
# Out:
# '1989-11-13'

# %%
song.title
# Out:
# 'A Bitch Iz a Bitch'

# %%
song.song_art_image_url
# Out:
# 'https://images.genius.com/1eeb76b08dcbc4e778777a3be33bdff4.600x600x1.jpg'

# %%
song.lyrics.split('\n')
# Out:
# ['[Narrator]',
#  "Let's describe a certain female",
#  'A female with a disease of character and attitude',
#  'If you will a snob',
#  'However in the view of NWA...',
#  '',
#  '[Verse 1: Ice Cube]',
#  'A bitch is a bitch',
#  "So if I'm poor or rich",
#  'I talk in the exact same pitch',
#  "Now the title bitch don't apply to all women",
#  "But all women have a little bitch in 'em",
#  "It's like a disease that plagues their character",
#  'Taking the women of America',
#  'And it starts with the letter B',
#  'It makes a girl like that think she better than me (bitch)',
#  'See, some get mad and some just bear it',
#  'But, yo, if the shoe fits wear it',
#  "It makes 'em go deaf in the ear that's why",
#  "When you say 'hi' she won't say 'hi'",
#  "Are you the kind that think you're too damn fly?",
#  'Bitch eat shit and die',
#  'Ice Cube coming at you at a crazy pitch',
#  '(Why?) I think a bitch is a bitch',
#  '',
#  '[Bitch]',
#  'Who the fuck you think you calling a bitch you little sorry motherfucker',
#  "I don't know who the fuck you think you talking to",
#  "Let me tell you one motherfucking thing, I'm not no-",
#  '"Bitch, shut the fuck up"',
#  '',
#  '[Verse 2: Ice Cube]',
#  "Yo, you can tell a girl that's out for the money",
#  'She look good and the bitch walk funny',
#  "She ain't no dummy, she's rather conniving",
#  "Yo bitch, fuck what I'm driving",
#  "See a young nigga that's striving",
#  "You're through without a BMW",
#  "That's why a bitch is a bitch I guess",
#  'Or either P-M-S',
#  "Here, test the girl that's kinda snobby",
#  'And I bet you dissing niggas is her hobby',
#  'And after she finished the test',
#  'Grade today of B-I-T-C-H',
#  "And watch her get mad 'cause she know it's true (she know it)",
#  'But a nigga like me\'ll say "fuck you"',
#  'Do like Ice Cube, slam her ass in a ditch (word) (slam her ass)',
#  "'Cause a bitch is a bitch",
#  '',
#  '[Bitch/Ice Cube]',
#  '"Why I gotta be a bitch?"',
#  "I ain't call you no bitch, if you listen to the goddamn song it'd tell you what a bitch is...",
#  '"Fuck the song \'cause I\'m not no motherfucking bitch"',
#  "I didn't say you was a bitch, if you stop acting like a goddamn bitch",
#  '"Fuck you, little punk-ass little nigga"',
#  'Fuck you, bitch! You sloppy-ass, scandalous-ass ho!',
#  '"Fuck you! Who the fuck you think you are?"',
#  'Fuck you! Suck my dick, bitch! You scandalous-ass, doo-doo dog breath, stinking, ugly...',
#  '',
#  '[Verse 3: Ice Cube]',
#  'I once knew a bitch who got slapped',
#  "'Cause she played me like she was all that",
#  'A bitch can be your best friend talking behind your back (yeah?)',
#  "About who's fucking who and who's getting fat",
#  'Look at yourself for me (look, bitch)',
#  'Now do you fall in this category?',
#  "Or you the kind that won't blink",
#  "'Cause you don't think your shit stink",
#  "Lucky I haven't had a drink",
#  "'Cause I'd down your ass",
#  "Then I'd clown your ass",
#  "'Cause the niggas I hang with ain't rich",
#  'We\'ll all say "Fuck you bitch!" (word)',
#  'Now what can I do with a ho like you',
#  "Bend your ass over and then I'm through (get the fuck out)",
#  "'Cause you see Ice Cube ain't taking no shit",
#  "(Why?) 'Cause I think a bitch is a bitch",
#  '',
#  '[Narrator]',
#  'There you have it, the description of a bitch',
#  'Now ask yourself are they talking about you?',
#  'Are you that funky, dirty, money-hungry, scandalous, stuck-up, hair piece contact wearing bitch?',
#  'Yep, you probably are',
#  '',
#  'Bitch!']

# %%
import requests
import urllib

# Format a request URI for the Genius API
search_term = 'A Bitch Iz a Bitch'
_URL_API = "https://api.genius.com/"
_URL_SEARCH = "search?q="
querystring = _URL_API + _URL_SEARCH + urllib.parse.quote(search_term)
request = urllib.request.Request(querystring)
request.add_header("Authorization", "Bearer " + 'EkwclsJky_nfkcWhnpOfQu-99mxmOPMe6r_gcPxPUOxtVslEytkjhzBvTOjxzBhn')
request.add_header("User-Agent", "")

# %%
response = urllib.request.urlopen(request, timeout=3)

# %%
import json
json.loads(json.dumps(response.readline()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-3538aa001ce5> in <module>()
#       1 import json
# ----> 2 json.loads(json.dumps(response.readline()))
#
# ~\Anaconda3\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# ~\Anaconda3\lib\json\encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# ~\Anaconda3\lib\json\encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# ~\Anaconda3\lib\json\encoder.py in default(self, o)
#     178         """
#     179         raise TypeError("Object of type '%s' is not JSON serializable" %
# --> 180                         o.__class__.__name__)
#     181
#     182     def encode(self, o):
#
# TypeError: Object of type 'bytes' is not JSON serializable

# %%
str_ =response.readline().decode('utf-8')

# %%
json.loads(str_)
# Out:
# {'meta': {'status': 200},
#  'response': {'hits': [{'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 16,
#      'api_path': '/songs/5399',
#      'full_title': 'A Bitch Iz a Bitch by\xa0N.W.A',
#      'header_image_thumbnail_url': 'https://images.genius.com/1eeb76b08dcbc4e778777a3be33bdff4.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/1eeb76b08dcbc4e778777a3be33bdff4.600x600x1.jpg',
#      'id': 5399,
#      'lyrics_owner_id': 8534,
#      'lyrics_state': 'complete',
#      'path': '/Nwa-a-bitch-iz-a-bitch-lyrics',
#      'pyongs_count': 14,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/1eeb76b08dcbc4e778777a3be33bdff4.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 1, 'pageviews': 102181},
#      'title': 'A Bitch Iz a Bitch',
#      'title_with_featured': 'A Bitch Iz a Bitch',
#      'url': 'https://genius.com/Nwa-a-bitch-iz-a-bitch-lyrics',
#      'primary_artist': {'api_path': '/artists/974',
#       'header_image_url': 'https://images.genius.com/64775e3e9a675ae6b080c88a743d982a.600x200x1.jpg',
#       'id': 974,
#       'image_url': 'https://images.genius.com/627acab300f5f3fd378a3b1adf4a69f8.630x630x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'N.W.A',
#       'url': 'https://genius.com/artists/Nwa'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 32,
#      'api_path': '/songs/3842',
#      'full_title': 'Ice Cube Killa by\xa0Cypress\xa0Hill',
#      'header_image_thumbnail_url': 'https://images.genius.com/31f0c96f104adee3fbc11447cbf3eebc.300x169x1.jpg',
#      'header_image_url': 'https://images.genius.com/31f0c96f104adee3fbc11447cbf3eebc.1000x563x1.jpg',
#      'id': 3842,
#      'lyrics_owner_id': 2437,
#      'lyrics_state': 'complete',
#      'path': '/Cypress-hill-ice-cube-killa-lyrics',
#      'pyongs_count': 3,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/31f0c96f104adee3fbc11447cbf3eebc.300x169x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 7, 'pageviews': 19549},
#      'title': 'Ice Cube Killa',
#      'title_with_featured': 'Ice Cube Killa',
#      'url': 'https://genius.com/Cypress-hill-ice-cube-killa-lyrics',
#      'primary_artist': {'api_path': '/artists/1317',
#       'header_image_url': 'https://images.genius.com/ace91b03cd16b6f3678660cd184af26a.500x323x1.jpg',
#       'id': 1317,
#       'image_url': 'https://images.genius.com/ace91b03cd16b6f3678660cd184af26a.500x323x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Cypress Hill',
#       'url': 'https://genius.com/artists/Cypress-hill'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 16,
#      'api_path': '/songs/2468987',
#      'full_title': 'Do it All (Song titles) by\xa0Derek\xa0Coleman',
#      'header_image_thumbnail_url': 'https://images.genius.com/4559fb548131c02cae74d32936fd135e.300x63x1.jpg',
#      'header_image_url': 'https://images.genius.com/4559fb548131c02cae74d32936fd135e.1000x210x1.jpg',
#      'id': 2468987,
#      'lyrics_owner_id': 2581893,
#      'lyrics_state': 'complete',
#      'path': '/Derek-coleman-do-it-all-song-titles-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/e9327f42c857d127454c093d0149a12c.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 16},
#      'title': 'Do it All (Song titles)',
#      'title_with_featured': 'Do it All (Song titles)',
#      'url': 'https://genius.com/Derek-coleman-do-it-all-song-titles-lyrics',
#      'primary_artist': {'api_path': '/artists/666131',
#       'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1540847173',
#       'id': 666131,
#       'image_url': 'https://assets.genius.com/images/default_avatar_300.png?1540847173',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Derek Coleman',
#       'url': 'https://genius.com/artists/Derek-coleman'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/663677',
#      'full_title': 'Bitch Iz a Bitch by\xa0Bone\xa0Thugs-N-Harmony',
#      'header_image_thumbnail_url': 'https://images.genius.com/c96ac4be7f9200d025c7bfc2be1bb566.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/c96ac4be7f9200d025c7bfc2be1bb566.1000x1000x1.jpg',
#      'id': 663677,
#      'lyrics_owner_id': 4460628,
#      'lyrics_state': 'complete',
#      'path': '/Bone-thugs-n-harmony-bitch-iz-a-bitch-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/c96ac4be7f9200d025c7bfc2be1bb566.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'Bitch Iz a Bitch',
#      'title_with_featured': 'Bitch Iz a Bitch',
#      'url': 'https://genius.com/Bone-thugs-n-harmony-bitch-iz-a-bitch-lyrics',
#      'primary_artist': {'api_path': '/artists/64',
#       'header_image_url': 'https://s3.amazonaws.com/rapgenius/Bone_Thugs.jpg',
#       'id': 64,
#       'image_url': 'https://s3.amazonaws.com/rapgenius/Bone_Thugs.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bone Thugs-N-Harmony',
#       'url': 'https://genius.com/artists/Bone-thugs-n-harmony'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/1562512',
#      'full_title': 'Payback Iz a Bitch (feat. Bam) by\xa0Krayzie\xa0Bone',
#      'header_image_thumbnail_url': 'https://images.genius.com/c2da063bfa8fc858df11986f83a3e5f4.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/c2da063bfa8fc858df11986f83a3e5f4.395x395x1.jpg',
#      'id': 1562512,
#      'lyrics_owner_id': 1549345,
#      'lyrics_state': 'complete',
#      'path': '/Krayzie-bone-payback-iz-a-bitch-feat-bam-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/c2da063bfa8fc858df11986f83a3e5f4.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'Payback Iz a Bitch (feat. Bam)',
#      'title_with_featured': 'Payback Iz a Bitch (feat. Bam)',
#      'url': 'https://genius.com/Krayzie-bone-payback-iz-a-bitch-feat-bam-lyrics',
#      'primary_artist': {'api_path': '/artists/350',
#       'header_image_url': 'https://images.genius.com/c2da063bfa8fc858df11986f83a3e5f4.395x395x1.jpg',
#       'id': 350,
#       'image_url': 'https://images.genius.com/c2da063bfa8fc858df11986f83a3e5f4.395x395x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': True,
#       'name': 'Krayzie Bone',
#       'url': 'https://genius.com/artists/Krayzie-bone',
#       'iq': 177}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/1402835',
#      'full_title': 'Payback Iz A Bitch by\xa0Krayzie\xa0Bone',
#      'header_image_thumbnail_url': 'https://images.genius.com/c2da063bfa8fc858df11986f83a3e5f4.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/c2da063bfa8fc858df11986f83a3e5f4.395x395x1.jpg',
#      'id': 1402835,
#      'lyrics_owner_id': 1549345,
#      'lyrics_state': 'complete',
#      'path': '/Krayzie-bone-payback-iz-a-bitch-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/c2da063bfa8fc858df11986f83a3e5f4.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'Payback Iz A Bitch',
#      'title_with_featured': 'Payback Iz A Bitch',
#      'url': 'https://genius.com/Krayzie-bone-payback-iz-a-bitch-lyrics',
#      'primary_artist': {'api_path': '/artists/350',
#       'header_image_url': 'https://images.genius.com/c2da063bfa8fc858df11986f83a3e5f4.395x395x1.jpg',
#       'id': 350,
#       'image_url': 'https://images.genius.com/c2da063bfa8fc858df11986f83a3e5f4.395x395x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': True,
#       'name': 'Krayzie Bone',
#       'url': 'https://genius.com/artists/Krayzie-bone',
#       'iq': 177}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 34,
#      'api_path': '/songs/1145',
#      'full_title': 'The Bitch in Yoo by\xa0Common',
#      'header_image_thumbnail_url': 'https://images.genius.com/ffdfad131f8495b65a7146dd3194b8b1.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/ffdfad131f8495b65a7146dd3194b8b1.595x595x1.jpg',
#      'id': 1145,
#      'lyrics_owner_id': 98,
#      'lyrics_state': 'complete',
#      'path': '/Common-the-bitch-in-yoo-lyrics',
#      'pyongs_count': 30,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/ffdfad131f8495b65a7146dd3194b8b1.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 8, 'pageviews': 60838},
#      'title': 'The Bitch in Yoo',
#      'title_with_featured': 'The Bitch in Yoo',
#      'url': 'https://genius.com/Common-the-bitch-in-yoo-lyrics',
#      'primary_artist': {'api_path': '/artists/223',
#       'header_image_url': 'https://images.genius.com/5eb3b5fd0cc65fbab5466d22c19278f1.1000x661x1.jpg',
#       'id': 223,
#       'image_url': 'https://images.genius.com/334bd07941665eb5b381fb51bced319d.1000x1000x1.jpg',
#       'is_meme_verified': True,
#       'is_verified': True,
#       'name': 'Common',
#       'url': 'https://genius.com/artists/Common',
#       'iq': 10412}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/205703',
#      'full_title': 'Record Report Albums: AMG - Bitch Better Have My Money by\xa0Reef (Ft.\xa0AMG)',
#      'header_image_thumbnail_url': 'https://assets.genius.com/images/default_cover_image.png?1540847173',
#      'header_image_url': 'https://assets.genius.com/images/default_cover_image.png?1540847173',
#      'id': 205703,
#      'lyrics_owner_id': 21564,
#      'lyrics_state': 'complete',
#      'path': '/Reef-record-report-albums-amg-bitch-better-have-my-money-annotated',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://assets.genius.com/images/default_cover_image.png?1540847173',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'Record Report Albums: AMG - Bitch Better Have My Money',
#      'title_with_featured': 'Record Report Albums: AMG - Bitch Better Have My Money (Ft.\xa0AMG)',
#      'url': 'https://genius.com/Reef-record-report-albums-amg-bitch-better-have-my-money-annotated',
#      'primary_artist': {'api_path': '/artists/237',
#       'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1540847173',
#       'id': 237,
#       'image_url': 'https://assets.genius.com/images/default_avatar_300.png?1540847173',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Reef',
#       'url': 'https://genius.com/artists/Reef'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/336257',
#      'full_title': 'Right Now by\xa0Trey\xa0Mash',
#      'header_image_thumbnail_url': 'https://assets.genius.com/images/default_cover_image.png?1540847173',
#      'header_image_url': 'https://assets.genius.com/images/default_cover_image.png?1540847173',
#      'id': 336257,
#      'lyrics_owner_id': 290551,
#      'lyrics_state': 'complete',
#      'path': '/Trey-mash-right-now-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://assets.genius.com/images/default_cover_image.png?1540847173',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'Right Now',
#      'title_with_featured': 'Right Now',
#      'url': 'https://genius.com/Trey-mash-right-now-lyrics',
#      'primary_artist': {'api_path': '/artists/73902',
#       'header_image_url': 'https://images.rapgenius.com/avatars/medium/PM1hrcihSb6oOqOWoWHY',
#       'id': 73902,
#       'image_url': 'https://images.rapgenius.com/avatars/medium/PM1hrcihSb6oOqOWoWHY',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Trey Mash',
#       'url': 'https://genius.com/artists/Trey-mash',
#       'iq': 130}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/3403182',
#      'full_title': 'SH.U.T by\xa0Latelatekuro',
#      'header_image_thumbnail_url': 'https://images.genius.com/6513844bd4b16a63554031fc5b1b4d1c.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/6513844bd4b16a63554031fc5b1b4d1c.1000x1000x1.jpg',
#      'id': 3403182,
#      'lyrics_owner_id': 5494695,
#      'lyrics_state': 'complete',
#      'path': '/Latelatekuro-shut-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/6513844bd4b16a63554031fc5b1b4d1c.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'SH.U.T',
#      'title_with_featured': 'SH.U.T',
#      'url': 'https://genius.com/Latelatekuro-shut-lyrics',
#      'primary_artist': {'api_path': '/artists/1273460',
#       'header_image_url': 'https://images.genius.com/e5ce0a4c17299d79ba1d5c2acedbb9d5.1000x754x1.png',
#       'id': 1273460,
#       'image_url': 'https://images.genius.com/e5ce0a4c17299d79ba1d5c2acedbb9d5.1000x754x1.png',
#       'is_meme_verified': False,
#       'is_verified': True,
#       'name': 'Latelatekuro',
#       'url': 'https://genius.com/artists/Latelatekuro',
#       'iq': 4850}}}]}}

# %%
# Format a request URI for the Genius API
search_term = 'A Bitch Iz a Bitch'
_URL_API = "https://api.genius.com/songs/5399"
_URL_SEARCH = "search?q="
querystring = _URL_API + _URL_SEARCH + urllib.parse.quote(search_term)
request = urllib.request.Request(querystring)
request.add_header("Authorization", "Bearer " + 'EkwclsJky_nfkcWhnpOfQu-99mxmOPMe6r_gcPxPUOxtVslEytkjhzBvTOjxzBhn')
request.add_header("User-Agent", "")

# %%
response = urllib.request.urlopen(request, timeout=3)

# %%
str_2 =response.readline().decode('utf-8')

# %%
json.loads(str_2)
# Out:
# {'meta': {'status': 200},
#  'response': {'song': {'annotation_count': 16,
#    'api_path': '/songs/5399',
#    'apple_music_id': '1005226222',
#    'apple_music_player_url': 'https://genius.com/songs/5399/apple_music_player',
#    'description': {'dom': {'tag': 'root',
#      'children': [{'tag': 'p',
#        'children': ['This fantastically gangster track from Ice Cube is featured on N.W.A’s famous Ruthless Records release, [Straight Outta Compton] as a Bonus Track.']},
#       '',
#       {'tag': 'p',
#        'children': ['This track is narrated by a very white-sounding man, making it a perfect response to outsider attacks on hip-hop for being misogynist and also to feminists that condone using the word “bitch” to describe women as completely inappropriate and unacceptable.']},
#       '',
#       {'tag': 'p',
#        'children': ['Ice Cube, however, offers a counter: his definition of a “bitch” is not what you think. He is not saying all women are bitches, he simply believes that sometimes, a bitch iz a bitch. He describes it as a “disease plaguing their character”, almost making women victims in the situation.']},
#       '',
#       {'tag': 'p',
#        'children': ['Acting like a bitch involves any combination of acting conniving, using men for money, dissing men, gossiping about friends, wearing scandalous clothing, being stuck-up, and wearing contacts. Ice Cube does not blame women for being that way, as it is only the natural. But he will not hesitate calling out women for acting in this manner.']}]}},
#    'embed_content': "<div id='rg_embed_link_5399' class='rg_embed_link' data-song-id='5399'>Read <a href='https://genius.com/Nwa-a-bitch-iz-a-bitch-lyrics'>“A Bitch Iz a Bitch” by N.W.A</a> on Genius</div> <script crossorigin src='//genius.com/songs/5399/embed.js'></script>",
#    'featured_video': False,
#    'full_title': 'A Bitch Iz a Bitch by\xa0N.W.A',
#    'header_image_thumbnail_url': 'https://images.genius.com/1eeb76b08dcbc4e778777a3be33bdff4.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/1eeb76b08dcbc4e778777a3be33bdff4.600x600x1.jpg',
#    'id': 5399,
#    'lyrics_owner_id': 8534,
#    'lyrics_state': 'complete',
#    'path': '/Nwa-a-bitch-iz-a-bitch-lyrics',
#    'pyongs_count': 14,
#    'recording_location': 'Audio Achievements (Torrance, CA)',
#    'release_date': '1989-11-13',
#    'song_art_image_thumbnail_url': 'https://images.genius.com/1eeb76b08dcbc4e778777a3be33bdff4.300x300x1.jpg',
#    'song_art_image_url': 'https://images.genius.com/1eeb76b08dcbc4e778777a3be33bdff4.600x600x1.jpg',
#    'stats': {'accepted_annotations': 14,
#     'contributors': 55,
#     'hot': False,
#     'iq_earners': 55,
#     'transcribers': 0,
#     'unreviewed_annotations': 1,
#     'verified_annotations': 0,
#     'pageviews': 102184},
#    'title': 'A Bitch Iz a Bitch',
#    'title_with_featured': 'A Bitch Iz a Bitch',
#    'url': 'https://genius.com/Nwa-a-bitch-iz-a-bitch-lyrics',
#    'current_user_metadata': {'permissions': ['see_pageviews',
#      'view_apple_music_player',
#      'create_comment',
#      'view_song_story_gallery'],
#     'excluded_permissions': ['follow',
#      'award_transcription_iq',
#      'remove_transcription_iq',
#      'pyong',
#      'edit_lyrics',
#      'view_annotation_engagement_data',
#      'publish',
#      'unpublish',
#      'edit_spotify_details',
#      'hide',
#      'unhide',
#      'toggle_featured_video',
#      'add_pinned_annotation_to',
#      'add_community_annotation_to',
#      'destroy',
#      'mark_as_not_spam',
#      'edit_spotify_annotations_for',
#      'verify_lyrics',
#      'unverify_lyrics',
#      'edit_anything',
#      'edit_album_appearances',
#      'edit_any_media',
#      'edit',
#      'rename',
#      'edit_tags',
#      'watch_fact_track',
#      'reindex',
#      'view_lyrics_synchronization',
#      'enable_media',
#      'disable_media',
#      'edit_lyrics_or_annotation_brackets',
#      'see_editorial_indicators',
#      'view_attribution_visualization',
#      'edit_annotation_brackets',
#      'preview_lyrics_for_export',
#      'hide_apple_player',
#      'unhide_apple_player',
#      'trigger_apple_match',
#      'mark_lyrics_evaluation_as_approved',
#      'mark_lyrics_evaluation_as_staff_approved',
#      'mark_lyrics_evaluation_as_unapproved',
#      'mark_lyrics_evaluation_as_un_staff_approved',
#      'edit_youtube_url',
#      'edit_soundcloud_url',
#      'edit_spotify_uuid',
#      'edit_vevo_url',
#      'moderate_annotations',
#      'create_annotation',
#      'see_short_id',
#      'manage_chart_item',
#      'create_tag',
#      'propose_lyrics_edit',
#      'moderate_lyrics_edit_proposals'],
#     'interactions': {'pyong': False, 'following': False},
#     'relationships': {},
#     'iq_by_action': {}},
#    'album': {'api_path': '/albums/7236',
#     'cover_art_url': 'https://images.genius.com/1c81d51b13dc4236b4af0e1838b85b8c.600x600x1.jpg',
#     'full_title': 'N.W.A. And The Posse by N.W.A',
#     'id': 7236,
#     'name': 'N.W.A. And The Posse',
#     'url': 'https://genius.com/albums/Nwa/N-w-a-and-the-posse',
#     'artist': {'api_path': '/artists/974',
#      'header_image_url': 'https://images.genius.com/64775e3e9a675ae6b080c88a743d982a.600x200x1.jpg',
#      'id': 974,
#      'image_url': 'https://images.genius.com/627acab300f5f3fd378a3b1adf4a69f8.630x630x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'N.W.A',
#      'url': 'https://genius.com/artists/Nwa'}},
#    'custom_performances': [{'label': 'Engineer',
#      'artists': [{'api_path': '/artists/1014656',
#        'header_image_url': 'https://images.genius.com/9a849f95a258c1585a6737c702796d11.148x148x1.jpg',
#        'id': 1014656,
#        'image_url': 'https://images.genius.com/9a849f95a258c1585a6737c702796d11.148x148x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Donovan "Tha Dirtbiker" Sound',
#        'url': 'https://genius.com/artists/Donovan-tha-dirtbiker-sound'}]},
#     {'label': 'Mastering Engineer',
#      'artists': [{'api_path': '/artists/637914',
#        'header_image_url': 'https://images.genius.com/14b89e85011c34e3a891ba144862d6db.300x214x1.jpg',
#        'id': 637914,
#        'image_url': 'https://images.genius.com/edeef8fedbd6d77ce67179af9e7549a2.172x172x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': '"Big Bass" Brian Gardner',
#        'url': 'https://genius.com/artists/Big-bass-brian-gardner'}]},
#     {'label': 'Label',
#      'artists': [{'api_path': '/artists/995712',
#        'header_image_url': 'https://images.genius.com/d0a52f846ffb03fd291b63e3e88005be.500x178x1.jpg',
#        'id': 995712,
#        'image_url': 'https://images.genius.com/1eabd5f60c56cbd6eba06adc3e2adbee.360x360x1.png',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Ruthless Records',
#        'url': 'https://genius.com/artists/Ruthless-records'},
#       {'api_path': '/artists/253580',
#        'header_image_url': 'https://images.genius.com/2ea6a296a9e3b9c94306c55a40158da7.600x400x1.jpg',
#        'id': 253580,
#        'image_url': 'https://images.genius.com/bdb3b8fb17006c630bfd55aa21457ca5.600x600x1.png',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Priority Records',
#        'url': 'https://genius.com/artists/Priority-records'}]}],
#    'description_annotation': {'_type': 'referent',
#     'annotator_id': 14740,
#     'annotator_login': 'GeniusJoe12',
#     'api_path': '/referents/3495364',
#     'classification': 'accepted',
#     'fragment': 'A Bitch Iz a Bitch',
#     'id': 3495364,
#     'is_description': True,
#     'path': '/3495364/Nwa-a-bitch-iz-a-bitch/A-bitch-iz-a-bitch',
#     'range': {'content': 'A Bitch Iz a Bitch'},
#     'song_id': 5399,
#     'url': 'https://genius.com/3495364/Nwa-a-bitch-iz-a-bitch/A-bitch-iz-a-bitch',
#     'verified_annotator_ids': [],
#     'annotatable': {'api_path': '/songs/5399',
#      'client_timestamps': {'updated_by_human_at': 1529648732,
#       'lyrics_updated_at': 1529648732},
#      'context': 'N.W.A',
#      'id': 5399,
#      'image_url': 'https://images.genius.com/1eeb76b08dcbc4e778777a3be33bdff4.600x600x1.jpg',
#      'link_title': 'A Bitch Iz a Bitch by\xa0N.W.A',
#      'title': 'A Bitch Iz a Bitch',
#      'type': 'Song',
#      'url': 'https://genius.com/Nwa-a-bitch-iz-a-bitch-lyrics'},
#     'annotations': [{'api_path': '/annotations/3495364',
#       'body': {'dom': {'tag': 'root',
#         'children': [{'tag': 'p',
#           'children': ['This fantastically gangster track from Ice Cube is featured on N.W.A’s famous Ruthless Records release, [Straight Outta Compton] as a Bonus Track.']},
#          '',
#          {'tag': 'p',
#           'children': ['This track is narrated by a very white-sounding man, making it a perfect response to outsider attacks on hip-hop for being misogynist and also to feminists that condone using the word “bitch” to describe women as completely inappropriate and unacceptable.']},
#          '',
#          {'tag': 'p',
#           'children': ['Ice Cube, however, offers a counter: his definition of a “bitch” is not what you think. He is not saying all women are bitches, he simply believes that sometimes, a bitch iz a bitch. He describes it as a “disease plaguing their character”, almost making women victims in the situation.']},
#          '',
#          {'tag': 'p',
#           'children': ['Acting like a bitch involves any combination of acting conniving, using men for money, dissing men, gossiping about friends, wearing scandalous clothing, being stuck-up, and wearing contacts. Ice Cube does not blame women for being that way, as it is only the natural. But he will not hesitate calling out women for acting in this manner.']}]}},
#       'comment_count': 1,
#       'community': True,
#       'custom_preview': None,
#       'has_voters': True,
#       'id': 3495364,
#       'pinned': False,
#       'share_url': 'https://genius.com/3495364',
#       'source': None,
#       'state': 'accepted',
#       'url': 'https://genius.com/3495364/Nwa-a-bitch-iz-a-bitch/A-bitch-iz-a-bitch',
#       'verified': False,
#       'votes_total': 11,
#       'current_user_metadata': {'permissions': ['create_comment'],
#        'excluded_permissions': ['vote',
#         'edit',
#         'cosign',
#         'uncosign',
#         'destroy',
#         'accept',
#         'reject',
#         'see_unreviewed',
#         'clear_votes',
#         'propose_edit_to',
#         'pin_to_profile',
#         'unpin_from_profile',
#         'update_source',
#         'edit_custom_preview'],
#        'interactions': {'cosign': False, 'pyong': False, 'vote': None},
#        'iq_by_action': {}},
#       'authors': [{'attribution': 1.0,
#         'pinned_role': None,
#         'user': {'api_path': '/users/14740',
#          'avatar': {'tiny': {'url': 'https://images.rapgenius.com/avatars/tiny/224438d230bd16ac7965850c75bc8de2',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.rapgenius.com/avatars/thumb/224438d230bd16ac7965850c75bc8de2',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.rapgenius.com/avatars/small/224438d230bd16ac7965850c75bc8de2',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.rapgenius.com/avatars/medium/224438d230bd16ac7965850c75bc8de2',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://images.rapgenius.com/avatars/medium/224438d230bd16ac7965850c75bc8de2',
#          'human_readable_role_for_display': 'Contributor',
#          'id': 14740,
#          'iq': 12848,
#          'login': 'GeniusJoe12',
#          'name': 'GeniusJoe12',
#          'role_for_display': 'contributor',
#          'url': 'https://genius.com/GeniusJoe12',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False},
#           'features': []}}}],
#       'cosigned_by': [],
#       'rejection_comment': None,
#       'verified_by': None}]},
#    'featured_artists': [],
#    'media': [{'native_uri': 'spotify:track:1PuEFAx07EIWrtdfdUexVS',
#      'provider': 'spotify',
#      'type': 'audio',
#      'url': 'https://open.spotify.com/track/1PuEFAx07EIWrtdfdUexVS'},
#     {'provider': 'youtube',
#      'start': 0,
#      'type': 'video',
#      'url': 'http://www.youtube.com/watch?v=To5bUpOEHcw'}],
#    'primary_artist': {'api_path': '/artists/974',
#     'header_image_url': 'https://images.genius.com/64775e3e9a675ae6b080c88a743d982a.600x200x1.jpg',
#     'id': 974,
#     'image_url': 'https://images.genius.com/627acab300f5f3fd378a3b1adf4a69f8.630x630x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'N.W.A',
#     'url': 'https://genius.com/artists/Nwa'},
#    'producer_artists': [{'api_path': '/artists/7973',
#      'header_image_url': 'https://images.genius.com/dddfcd76a5faa9f37e901682fed74be3.500x296x1.jpg',
#      'id': 7973,
#      'image_url': 'https://images.genius.com/b01bfae15b257e0bed6a425028953655.761x761x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'DJ Yella',
#      'url': 'https://genius.com/artists/Dj-yella'},
#     {'api_path': '/artists/123',
#      'header_image_url': 'https://images.genius.com/d7ba77150e7d10d29dca244a8cdc42f2.640x480x1.jpg',
#      'id': 123,
#      'image_url': 'https://images.genius.com/bf3badae49c33b583126057638078bd8.576x576x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Dr.\xa0Dre',
#      'url': 'https://genius.com/artists/Dr-dre'}],
#    'song_relationships': [{'type': 'samples',
#      'songs': [{'annotation_count': 55,
#        'api_path': '/songs/4015',
#        'full_title': 'Eazy Duz It by\xa0Eazy-E',
#        'header_image_thumbnail_url': 'https://images.genius.com/a661728c1a24d216b4bccc25aed59a70.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/a661728c1a24d216b4bccc25aed59a70.600x600x1.jpg',
#        'id': 4015,
#        'lyrics_owner_id': 5716,
#        'lyrics_state': 'complete',
#        'path': '/Eazy-e-eazy-duz-it-lyrics',
#        'pyongs_count': 14,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/9d5c027168b73d441f5a2e83bb705a94.300x300x1.jpg',
#        'stats': {'hot': False,
#         'unreviewed_annotations': 5,
#         'pageviews': 119392},
#        'title': 'Eazy Duz It',
#        'title_with_featured': 'Eazy Duz It',
#        'url': 'https://genius.com/Eazy-e-eazy-duz-it-lyrics',
#        'primary_artist': {'api_path': '/artists/496',
#         'header_image_url': 'https://images.genius.com/5838a6ab3478cca8c897bcf13fd035fd.1000x563x1.jpg',
#         'id': 496,
#         'image_url': 'https://images.genius.com/6df666056600c0dd44be4e74dec323a6.439x504x1.png',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Eazy-E',
#         'url': 'https://genius.com/artists/Eazy-e'}},
#       {'annotation_count': 48,
#        'api_path': '/songs/4886',
#        'full_title': 'Gangsta Gangsta by\xa0N.W.A',
#        'header_image_thumbnail_url': 'https://images.genius.com/845c60a34ea88b98e594ea44eef7b6ff.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/845c60a34ea88b98e594ea44eef7b6ff.1000x1000x1.jpg',
#        'id': 4886,
#        'lyrics_owner_id': 7338,
#        'lyrics_state': 'complete',
#        'path': '/Nwa-gangsta-gangsta-lyrics',
#        'pyongs_count': 30,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/fd371d42dce5252e7c95d0f36b740f46.300x302x1.jpg',
#        'stats': {'hot': False,
#         'unreviewed_annotations': 14,
#         'pageviews': 401003},
#        'title': 'Gangsta Gangsta',
#        'title_with_featured': 'Gangsta Gangsta',
#        'url': 'https://genius.com/Nwa-gangsta-gangsta-lyrics',
#        'primary_artist': {'api_path': '/artists/974',
#         'header_image_url': 'https://images.genius.com/64775e3e9a675ae6b080c88a743d982a.600x200x1.jpg',
#         'id': 974,
#         'image_url': 'https://images.genius.com/627acab300f5f3fd378a3b1adf4a69f8.630x630x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'N.W.A',
#         'url': 'https://genius.com/artists/Nwa'}}]},
#     {'type': 'sampled_in',
#      'songs': [{'annotation_count': 73,
#        'api_path': '/songs/761',
#        'full_title': 'No Vaseline by\xa0Ice\xa0Cube',
#        'header_image_thumbnail_url': 'https://images.rapgenius.com/89a02ab603eae95e0d380fcd08eda589.300x300x1.jpg',
#        'header_image_url': 'https://images.rapgenius.com/89a02ab603eae95e0d380fcd08eda589.1000x1000x1.jpg',
#        'id': 761,
#        'lyrics_owner_id': 511,
#        'lyrics_state': 'complete',
#        'path': '/Ice-cube-no-vaseline-lyrics',
#        'pyongs_count': 80,
#        'song_art_image_thumbnail_url': 'https://images.rapgenius.com/89a02ab603eae95e0d380fcd08eda589.300x300x1.jpg',
#        'stats': {'hot': False,
#         'unreviewed_annotations': 4,
#         'pageviews': 1272093},
#        'title': 'No Vaseline',
#        'title_with_featured': 'No Vaseline',
#        'url': 'https://genius.com/Ice-cube-no-vaseline-lyrics',
#        'primary_artist': {'api_path': '/artists/186',
#         'header_image_url': 'https://images.genius.com/c457bbdb72f694aa2707c388b36e7230.960x764x1.jpg',
#         'id': 186,
#         'image_url': 'https://images.genius.com/c457bbdb72f694aa2707c388b36e7230.960x764x1.jpg',
#         'is_meme_verified': True,
#         'is_verified': True,
#         'name': 'Ice Cube',
#         'url': 'https://genius.com/artists/Ice-cube',
#         'iq': 2590}},
#       {'annotation_count': 9,
#        'api_path': '/songs/8069',
#        'full_title': 'Bitch Betta Have My Money by\xa0AMG',
#        'header_image_thumbnail_url': 'https://images.genius.com/95140c7c576a68cc10d708ff71ef761a.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/95140c7c576a68cc10d708ff71ef761a.500x500x1.jpg',
#        'id': 8069,
#        'lyrics_owner_id': 50,
#        'lyrics_state': 'complete',
#        'path': '/Amg-bitch-betta-have-my-money-lyrics',
#        'pyongs_count': 10,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/95140c7c576a68cc10d708ff71ef761a.300x300x1.jpg',
#        'stats': {'hot': False,
#         'unreviewed_annotations': 1,
#         'pageviews': 133821},
#        'title': 'Bitch Betta Have My Money',
#        'title_with_featured': 'Bitch Betta Have My Money',
#        'url': 'https://genius.com/Amg-bitch-betta-have-my-money-lyrics',
#        'primary_artist': {'api_path': '/artists/216',
#         'header_image_url': 'https://images.genius.com/4ad8a802037ef3e900f32f99c8680aa5.230x300x1.jpg',
#         'id': 216,
#         'image_url': 'https://images.genius.com/77c974a765a7b9504a34a9d69eef8f49.230x230x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'AMG',
#         'url': 'https://genius.com/artists/Amg'}},
#       {'annotation_count': 12,
#        'api_path': '/songs/22590',
#        'full_title': 'The Nosebleed Section by\xa0Hilltop\xa0Hoods',
#        'header_image_thumbnail_url': 'https://images.genius.com/e90c0e2c1533ebf746b82c2156aa6870.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/e90c0e2c1533ebf746b82c2156aa6870.600x600x1.jpg',
#        'id': 22590,
#        'lyrics_owner_id': 50,
#        'lyrics_state': 'complete',
#        'path': '/Hilltop-hoods-the-nosebleed-section-lyrics',
#        'pyongs_count': 9,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/e90c0e2c1533ebf746b82c2156aa6870.300x300x1.jpg',
#        'stats': {'hot': False,
#         'unreviewed_annotations': 5,
#         'pageviews': 30829},
#        'title': 'The Nosebleed Section',
#        'title_with_featured': 'The Nosebleed Section',
#        'url': 'https://genius.com/Hilltop-hoods-the-nosebleed-section-lyrics',
#        'primary_artist': {'api_path': '/artists/4842',
#         'header_image_url': 'https://images.genius.com/ea0efbcf49a6651514a11d90c9bc706e.1000x260x1.jpg',
#         'id': 4842,
#         'image_url': 'https://images.genius.com/f008eb3d356a01d02e268c0bd54648d0.1000x1000x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Hilltop Hoods',
#         'url': 'https://genius.com/artists/Hilltop-hoods'}},
#       {'annotation_count': 2,
#        'api_path': '/songs/22620',
#        'full_title': 'Tolerance Levels by\xa0Hilltop\xa0Hoods (Ft.\xa0Flak & Mass\xa0MC)',
#        'header_image_thumbnail_url': 'https://images.genius.com/0f6cac6691d8daedb1412720393756b8.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/0f6cac6691d8daedb1412720393756b8.600x600x1.jpg',
#        'id': 22620,
#        'lyrics_owner_id': 50,
#        'lyrics_state': 'complete',
#        'path': '/Hilltop-hoods-tolerance-levels-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/0f6cac6691d8daedb1412720393756b8.300x300x1.jpg',
#        'stats': {'hot': False, 'unreviewed_annotations': 1},
#        'title': 'Tolerance Levels',
#        'title_with_featured': 'Tolerance Levels (Ft.\xa0Flak & Mass\xa0MC)',
#        'url': 'https://genius.com/Hilltop-hoods-tolerance-levels-lyrics',
#        'primary_artist': {'api_path': '/artists/4842',
#         'header_image_url': 'https://images.genius.com/ea0efbcf49a6651514a11d90c9bc706e.1000x260x1.jpg',
#         'id': 4842,
#         'image_url': 'https://images.genius.com/f008eb3d356a01d02e268c0bd54648d0.1000x1000x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Hilltop Hoods',
#         'url': 'https://genius.com/artists/Hilltop-hoods'}},
#       {'annotation_count': 24,
#        'api_path': '/songs/22935',
#        'full_title': "It's a Man's World by\xa0Ice\xa0Cube (Ft.\xa0Yo-Yo)",
#        'header_image_thumbnail_url': 'https://images.genius.com/daba771488301f2341dbce49714b74d7.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/daba771488301f2341dbce49714b74d7.635x635x1.jpg',
#        'id': 22935,
#        'lyrics_owner_id': 50,
#        'lyrics_state': 'complete',
#        'path': '/Ice-cube-its-a-mans-world-lyrics',
#        'pyongs_count': 1,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/daba771488301f2341dbce49714b74d7.300x300x1.jpg',
#        'stats': {'hot': False,
#         'unreviewed_annotations': 3,
#         'pageviews': 10137},
#        'title': "It's a Man's World",
#        'title_with_featured': "It's a Man's World (Ft.\xa0Yo-Yo)",
#        'url': 'https://genius.com/Ice-cube-its-a-mans-world-lyrics',
#        'primary_artist': {'api_path': '/artists/186',
#         'header_image_url': 'https://images.genius.com/c457bbdb72f694aa2707c388b36e7230.960x764x1.jpg',
#         'id': 186,
#         'image_url': 'https://images.genius.com/c457bbdb72f694aa2707c388b36e7230.960x764x1.jpg',
#         'is_meme_verified': True,
#         'is_verified': True,
#         'name': 'Ice Cube',
#         'url': 'https://genius.com/artists/Ice-cube',
#         'iq': 2590}},
#       {'annotation_count': 31,
#        'api_path': '/songs/22961',
#        'full_title': "Look Who's Burnin' by\xa0Ice\xa0Cube",
#        'header_image_thumbnail_url': 'https://images.rapgenius.com/89a02ab603eae95e0d380fcd08eda589.300x300x1.jpg',
#        'header_image_url': 'https://images.rapgenius.com/89a02ab603eae95e0d380fcd08eda589.1000x1000x1.jpg',
#        'id': 22961,
#        'lyrics_owner_id': 50,
#        'lyrics_state': 'complete',
#        'path': '/Ice-cube-look-whos-burnin-lyrics',
#        'pyongs_count': 1,
#        'song_art_image_thumbnail_url': 'https://images.rapgenius.com/89a02ab603eae95e0d380fcd08eda589.300x300x1.jpg',
#        'stats': {'hot': False, 'unreviewed_annotations': 3, 'pageviews': 9463},
#        'title': "Look Who's Burnin'",
#        'title_with_featured': "Look Who's Burnin'",
#        'url': 'https://genius.com/Ice-cube-look-whos-burnin-lyrics',
#        'primary_artist': {'api_path': '/artists/186',
#         'header_image_url': 'https://images.genius.com/c457bbdb72f694aa2707c388b36e7230.960x764x1.jpg',
#         'id': 186,
#         'image_url': 'https://images.genius.com/c457bbdb72f694aa2707c388b36e7230.960x764x1.jpg',
#         'is_meme_verified': True,
#         'is_verified': True,
#         'name': 'Ice Cube',
#         'url': 'https://genius.com/artists/Ice-cube',
#         'iq': 2590}},
#       {'annotation_count': 6,
#        'api_path': '/songs/23035',
#        'full_title': "Don't Trust Em by\xa0Ice\xa0Cube",
#        'header_image_thumbnail_url': 'https://images.genius.com/aa204256470ef9ed3c3a3fbcc1ee43da.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/aa204256470ef9ed3c3a3fbcc1ee43da.1000x1000x1.jpg',
#        'id': 23035,
#        'lyrics_owner_id': 50,
#        'lyrics_state': 'complete',
#        'path': '/Ice-cube-dont-trust-em-lyrics',
#        'pyongs_count': 1,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/aa204256470ef9ed3c3a3fbcc1ee43da.300x300x1.jpg',
#        'stats': {'hot': False, 'unreviewed_annotations': 1, 'pageviews': 6387},
#        'title': "Don't Trust Em",
#        'title_with_featured': "Don't Trust Em",
#        'url': 'https://genius.com/Ice-cube-dont-trust-em-lyrics',
#        'primary_artist': {'api_path': '/artists/186',
#         'header_image_url': 'https://images.genius.com/c457bbdb72f694aa2707c388b36e7230.960x764x1.jpg',
#         'id': 186,
#         'image_url': 'https://images.genius.com/c457bbdb72f694aa2707c388b36e7230.960x764x1.jpg',
#         'is_meme_verified': True,
#         'is_verified': True,
#         'name': 'Ice Cube',
#         'url': 'https://genius.com/artists/Ice-cube',
#         'iq': 2590}},
#       {'annotation_count': 0,
#        'api_path': '/songs/23664',
#        'full_title': 'For You by\xa0Joe\xa0Budden (Ft.\xa0Royce\xa0da 5’9”)',
#        'header_image_thumbnail_url': 'https://images.genius.com/607a1fcb47455bcc9a5f02f66001a9f4.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/607a1fcb47455bcc9a5f02f66001a9f4.1000x1000x1.jpg',
#        'id': 23664,
#        'lyrics_owner_id': 50,
#        'lyrics_state': 'complete',
#        'path': '/Joe-budden-for-you-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/607a1fcb47455bcc9a5f02f66001a9f4.300x300x1.jpg',
#        'stats': {'hot': False, 'unreviewed_annotations': 0},
#        'title': 'For You',
#        'title_with_featured': 'For You (Ft.\xa0Royce\xa0da 5’9”)',
#        'url': 'https://genius.com/Joe-budden-for-you-lyrics',
#        'primary_artist': {'api_path': '/artists/179',
#         'header_image_url': 'https://images.genius.com/ac6c8ba8d6aa88b06e5886a2840ed9f0.1000x428x1.jpg',
#         'id': 179,
#         'image_url': 'https://images.genius.com/43f9c82f7269ffb7397a0cc13844ec8d.513x513x1.jpg',
#         'is_meme_verified': True,
#         'is_verified': True,
#         'name': 'Joe Budden',
#         'url': 'https://genius.com/artists/Joe-budden',
#         'iq': 10356}},
#       {'annotation_count': 19,
#        'api_path': '/songs/24346',
#        'full_title': 'Da Bichez by\xa0Jeru\xa0The Damaja',
#        'header_image_thumbnail_url': 'https://images.genius.com/03c72ac1906a30e52dce84cfc7bc4318.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/03c72ac1906a30e52dce84cfc7bc4318.600x600x1.jpg',
#        'id': 24346,
#        'lyrics_owner_id': 50,
#        'lyrics_state': 'complete',
#        'path': '/Jeru-the-damaja-da-bichez-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/03c72ac1906a30e52dce84cfc7bc4318.300x300x1.jpg',
#        'stats': {'hot': False,
#         'unreviewed_annotations': 16,
#         'pageviews': 9482},
#        'title': 'Da Bichez',
#        'title_with_featured': 'Da Bichez',
#        'url': 'https://genius.com/Jeru-the-damaja-da-bichez-lyrics',
#        'primary_artist': {'api_path': '/artists/305',
#         'header_image_url': 'https://images.genius.com/e74354982276f3c70d4ab582de906573.500x500x1.png',
#         'id': 305,
#         'image_url': 'https://images.genius.com/e74354982276f3c70d4ab582de906573.500x500x1.png',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Jeru The Damaja',
#         'url': 'https://genius.com/artists/Jeru-the-damaja'}},
#       {'annotation_count': 19,
#        'api_path': '/songs/24504',
#        'full_title': 'Bitches & Sisters by\xa0JAY-Z',
#        'header_image_thumbnail_url': 'https://images.genius.com/bbaaa25ac55d3bc2008448e1647d3b54.300x263x1.jpg',
#        'header_image_url': 'https://images.genius.com/bbaaa25ac55d3bc2008448e1647d3b54.720x631x1.jpg',
#        'id': 24504,
#        'lyrics_owner_id': 50,
#        'lyrics_state': 'complete',
#        'path': '/Jay-z-bitches-and-sisters-lyrics',
#        'pyongs_count': 1,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/bbaaa25ac55d3bc2008448e1647d3b54.300x263x1.jpg',
#        'stats': {'hot': False,
#         'unreviewed_annotations': 0,
#         'pageviews': 51878},
#        'title': 'Bitches & Sisters',
#        'title_with_featured': 'Bitches & Sisters',
#        'url': 'https://genius.com/Jay-z-bitches-and-sisters-lyrics',
#        'primary_artist': {'api_path': '/artists/2',
#         'header_image_url': 'https://images.genius.com/57f67753a0fe8ce5ff4a2ab903fbe850.500x301x1.png',
#         'id': 2,
#         'image_url': 'https://images.genius.com/bf0f68ee56f29c8542ad805c6419682b.676x676x1.jpg',
#         'is_meme_verified': True,
#         'is_verified': True,
#         'name': 'JAY-Z',
#         'url': 'https://genius.com/artists/Jay-z',
#         'iq': 175}},
#       {'annotation_count': 30,
#        'api_path': '/songs/49321',
#        'full_title': 'Down 2 tha Last Roach by\xa0Eazy-E (Ft.\xa0B.G.\xa0Knocc Out & Dirty\xa0Red)',
#        'header_image_thumbnail_url': 'https://images.genius.com/68ec7968549a6cce7904e640a598ecb6.300x300x1.png',
#        'header_image_url': 'https://images.genius.com/68ec7968549a6cce7904e640a598ecb6.1000x1000x1.png',
#        'id': 49321,
#        'lyrics_owner_id': 12576,
#        'lyrics_state': 'complete',
#        'path': '/Eazy-e-down-2-tha-last-roach-lyrics',
#        'pyongs_count': 5,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/68ec7968549a6cce7904e640a598ecb6.300x300x1.png',
#        'stats': {'hot': False,
#         'unreviewed_annotations': 15,
#         'pageviews': 14317},
#        'title': 'Down 2 tha Last Roach',
#        'title_with_featured': 'Down 2 tha Last Roach (Ft.\xa0B.G.\xa0Knocc Out & Dirty\xa0Red)',
#        'url': 'https://genius.com/Eazy-e-down-2-tha-last-roach-lyrics',
#        'primary_artist': {'api_path': '/artists/496',
#         'header_image_url': 'https://images.genius.com/5838a6ab3478cca8c897bcf13fd035fd.1000x563x1.jpg',
#         'id': 496,
#         'image_url': 'https://images.genius.com/6df666056600c0dd44be4e74dec323a6.439x504x1.png',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Eazy-E',
#         'url': 'https://genius.com/artists/Eazy-e'}},
#       {'annotation_count': 11,
#        'api_path': '/songs/293516',
#        'full_title': 'Bang Out by\xa0Tyga (Ft.\xa0Eazy-E)',
#        'header_image_thumbnail_url': 'https://images.genius.com/934f724eda446a64483f52d66dfcf8ca.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/934f724eda446a64483f52d66dfcf8ca.475x475x1.jpg',
#        'id': 293516,
#        'lyrics_owner_id': 193036,
#        'lyrics_state': 'complete',
#        'path': '/Tyga-bang-out-lyrics',
#        'pyongs_count': 32,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/934f724eda446a64483f52d66dfcf8ca.300x300x1.jpg',
#        'stats': {'hot': False,
#         'unreviewed_annotations': 6,
#         'pageviews': 54737},
#        'title': 'Bang Out',
#        'title_with_featured': 'Bang Out (Ft.\xa0Eazy-E)',
#        'url': 'https://genius.com/Tyga-bang-out-lyrics',
#        'primary_artist': {'api_path': '/artists/554',
#         'header_image_url': 'https://images.genius.com/2232c935c94e05f96fa198329d2396d5.1000x752x1.jpg',
#         'id': 554,
#         'image_url': 'https://images.genius.com/bf240156bf229b0d64755f527126e748.646x646x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': True,
#         'name': 'Tyga',
#         'url': 'https://genius.com/artists/Tyga',
#         'iq': 717}},
#       {'annotation_count': 1,
#        'api_path': '/songs/875644',
#        'full_title': 'Even The Odd Found Love by\xa0Renard',
#        'header_image_thumbnail_url': 'https://images.genius.com/42c3622e171d3cdacafec2a63ee452dd.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/42c3622e171d3cdacafec2a63ee452dd.1000x1000x1.jpg',
#        'id': 875644,
#        'lyrics_owner_id': 1549345,
#        'lyrics_state': 'complete',
#        'path': '/Renard-even-the-odd-found-love-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/42c3622e171d3cdacafec2a63ee452dd.300x300x1.jpg',
#        'stats': {'hot': False, 'unreviewed_annotations': 0},
#        'title': 'Even The Odd Found Love',
#        'title_with_featured': 'Even The Odd Found Love',
#        'url': 'https://genius.com/Renard-even-the-odd-found-love-lyrics',
#        'primary_artist': {'api_path': '/artists/3593',
#         'header_image_url': 'https://images.genius.com/6f758f42df191d99a4bae2725295f845.600x600x1.jpg',
#         'id': 3593,
#         'image_url': 'https://images.genius.com/6f758f42df191d99a4bae2725295f845.600x600x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Renard',
#         'url': 'https://genius.com/artists/Renard'}},
#       {'annotation_count': 1,
#        'api_path': '/songs/2316239',
#        'full_title': 'Dies ist nicht Amerika by\xa0Beginner',
#        'header_image_thumbnail_url': 'https://images.genius.com/62072a12119a226d103097d274a4c664.300x298x1.jpg',
#        'header_image_url': 'https://images.genius.com/62072a12119a226d103097d274a4c664.300x298x1.jpg',
#        'id': 2316239,
#        'lyrics_owner_id': 248170,
#        'lyrics_state': 'complete',
#        'path': '/Beginner-dies-ist-nicht-amerika-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/62072a12119a226d103097d274a4c664.300x298x1.jpg',
#        'stats': {'hot': False, 'unreviewed_annotations': 0},
#        'title': 'Dies ist nicht Amerika',
#        'title_with_featured': 'Dies ist nicht Amerika',
#        'url': 'https://genius.com/Beginner-dies-ist-nicht-amerika-lyrics',
#        'primary_artist': {'api_path': '/artists/25183',
#         'header_image_url': 'https://s3.amazonaws.com/rapgenius/1355220276_photo.jpg',
#         'id': 25183,
#         'image_url': 'https://s3.amazonaws.com/rapgenius/1355220276_photo.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Beginner',
#         'url': 'https://genius.com/artists/Beginner'}},
#       {'annotation_count': 3,
#        'api_path': '/songs/2908795',
#        'full_title': 'The Real by\xa0Illy (Ft.\xa0Grey\xa0Ghost & MC\xa0Mantra)',
#        'header_image_thumbnail_url': 'https://images.genius.com/020f1e8dc6effff61d653c816b112f2a.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/020f1e8dc6effff61d653c816b112f2a.640x640x1.jpg',
#        'id': 2908795,
#        'lyrics_owner_id': 3017322,
#        'lyrics_state': 'complete',
#        'path': '/Illy-the-real-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/020f1e8dc6effff61d653c816b112f2a.300x300x1.jpg',
#        'stats': {'hot': False, 'unreviewed_annotations': 2},
#        'title': 'The Real',
#        'title_with_featured': 'The Real (Ft.\xa0Grey\xa0Ghost & MC\xa0Mantra)',
#        'url': 'https://genius.com/Illy-the-real-lyrics',
#        'primary_artist': {'api_path': '/artists/6644',
#         'header_image_url': 'https://images.genius.com/9597ae3e76ac2519dfd93274676de285.666x666x1.jpg',
#         'id': 6644,
#         'image_url': 'https://images.genius.com/9597ae3e76ac2519dfd93274676de285.666x666x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': True,
#         'name': 'Illy',
#         'url': 'https://genius.com/artists/Illy',
#         'iq': 100}},
#       {'annotation_count': 1,
#        'api_path': '/songs/2951895',
#        'full_title': 'Goutamafonkybite by\xa0Tout\xa0Simplement Noir',
#        'header_image_thumbnail_url': 'https://images.genius.com/d9e1cf19791aaaf4dfe076c85fc44429.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/d9e1cf19791aaaf4dfe076c85fc44429.500x500x1.jpg',
#        'id': 2951895,
#        'lyrics_owner_id': 3026682,
#        'lyrics_state': 'complete',
#        'path': '/Tout-simplement-noir-goutamafonkybite-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/d9e1cf19791aaaf4dfe076c85fc44429.300x300x1.jpg',
#        'stats': {'hot': False, 'unreviewed_annotations': 0},
#        'title': 'Goutamafonkybite',
#        'title_with_featured': 'Goutamafonkybite',
#        'url': 'https://genius.com/Tout-simplement-noir-goutamafonkybite-lyrics',
#        'primary_artist': {'api_path': '/artists/458078',
#         'header_image_url': 'https://images.genius.com/bc079052a7314421ba9d3e7e15dae012.331x331x1.jpg',
#         'id': 458078,
#         'image_url': 'https://images.genius.com/bc079052a7314421ba9d3e7e15dae012.331x331x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Tout Simplement Noir',
#         'url': 'https://genius.com/artists/Tout-simplement-noir'}},
#       {'annotation_count': 6,
#        'api_path': '/songs/3220627',
#        'full_title': "You Ain't Seen Nothing by\xa0K21 (Ft.\xa0Trials & Vents)",
#        'header_image_thumbnail_url': 'https://images.genius.com/198c1a9aa22993eb95eb9c4cb2d59d35.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/198c1a9aa22993eb95eb9c4cb2d59d35.300x300x1.jpg',
#        'id': 3220627,
#        'lyrics_owner_id': 4857736,
#        'lyrics_state': 'complete',
#        'path': '/K21-you-aint-seen-nothing-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/198c1a9aa22993eb95eb9c4cb2d59d35.300x300x1.jpg',
#        'stats': {'hot': False, 'unreviewed_annotations': 2},
#        'title': "You Ain't Seen Nothing",
#        'title_with_featured': "You Ain't Seen Nothing (Ft.\xa0Trials & Vents)",
#        'url': 'https://genius.com/K21-you-aint-seen-nothing-lyrics',
#        'primary_artist': {'api_path': '/artists/11450',
#         'header_image_url': 'https://images.genius.com/f8290441f1ab08fd4dec74d8012010c2.360x202x18.gif',
#         'id': 11450,
#         'image_url': 'https://images.genius.com/b8172e08ccbe01e3cb4203cbb82f8dda.533x533x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': True,
#         'name': 'K21',
#         'url': 'https://genius.com/artists/K21',
#         'iq': 129}}]},
#     {'type': 'interpolates', 'songs': []},
#     {'type': 'interpolated_by',
#      'songs': [{'annotation_count': 34,
#        'api_path': '/songs/1145',
#        'full_title': 'The Bitch in Yoo by\xa0Common',
#        'header_image_thumbnail_url': 'https://images.genius.com/ffdfad131f8495b65a7146dd3194b8b1.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/ffdfad131f8495b65a7146dd3194b8b1.595x595x1.jpg',
#        'id': 1145,
#        'lyrics_owner_id': 98,
#        'lyrics_state': 'complete',
#        'path': '/Common-the-bitch-in-yoo-lyrics',
#        'pyongs_count': 30,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/ffdfad131f8495b65a7146dd3194b8b1.300x300x1.jpg',
#        'stats': {'hot': False,
#         'unreviewed_annotations': 8,
#         'pageviews': 60838},
#        'title': 'The Bitch in Yoo',
#        'title_with_featured': 'The Bitch in Yoo',
#        'url': 'https://genius.com/Common-the-bitch-in-yoo-lyrics',
#        'primary_artist': {'api_path': '/artists/223',
#         'header_image_url': 'https://images.genius.com/5eb3b5fd0cc65fbab5466d22c19278f1.1000x661x1.jpg',
#         'id': 223,
#         'image_url': 'https://images.genius.com/334bd07941665eb5b381fb51bced319d.1000x1000x1.jpg',
#         'is_meme_verified': True,
#         'is_verified': True,
#         'name': 'Common',
#         'url': 'https://genius.com/artists/Common',
#         'iq': 10412}}]},
#     {'type': 'cover_of', 'songs': []},
#     {'type': 'covered_by', 'songs': []},
#     {'type': 'remix_of', 'songs': []},
#     {'type': 'remixed_by', 'songs': []},
#     {'type': 'live_version_of', 'songs': []},
#     {'type': 'performed_live_as', 'songs': []}],
#    'verified_annotations_by': [],
#    'verified_contributors': [],
#    'verified_lyrics_by': [],
#    'writer_artists': [{'api_path': '/artists/1436',
#      'header_image_url': 'https://images.genius.com/a722d2901f7522aa22febf9036d8ef9e.1000x563x1.jpg',
#      'id': 1436,
#      'image_url': 'https://images.genius.com/0775f581c14a33e3c5ed6bec9a85de49.353x353x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'MC Ren',
#      'url': 'https://genius.com/artists/Mc-ren'},
#     {'api_path': '/artists/186',
#      'header_image_url': 'https://images.genius.com/c457bbdb72f694aa2707c388b36e7230.960x764x1.jpg',
#      'id': 186,
#      'image_url': 'https://images.genius.com/c457bbdb72f694aa2707c388b36e7230.960x764x1.jpg',
#      'is_meme_verified': True,
#      'is_verified': True,
#      'name': 'Ice Cube',
#      'url': 'https://genius.com/artists/Ice-cube',
#      'iq': 2590}]}}}
